# %%
# %tensorflow_version 1.x
# !pip install stable-baselines[mps]==2.10.0
# !pip install numpy
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# absl-py                   2.2.2
# ale-py                    0.10.2
# anyio                     4.6.2
# appnope                   0.1.3
# argon2-cffi               21.3.0
# argon2-cffi-bindings      21.2.0
# asttokens                 3.0.0
# async-lru                 2.0.4
# attrs                     24.3.0
# babel                     2.16.0
# beautifulsoup4            4.12.3
# bleach                    6.2.0
# Brotli                    1.0.9
# certifi                   2025.1.31
# cffi                      1.17.1
# charset-normalizer        3.3.2
# cloudpickle               3.1.1
# comm                      0.2.1
# contourpy                 1.3.2
# cycler                    0.12.1
# debugpy                   1.8.11
# decorator                 5.1.1
# defusedxml                0.7.1
# executing                 0.8.3
# Farama-Notifications      0.0.4
# fastjsonschema            2.20.0
# ...

# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.policies import Mlp
